# %% [markdown]
# The goal of this file is to Solve the SDP problem
#
# Feasible
#
# Subject to:
# Pr(X - Y) = A_G
# tr(Y) <= k
#
# Fix 1's on the diagonal of the matrix and then solve for frasability using submatrices.

# %%
import sys
import os

# Add the parent folder of Semidef (the project root) to sys.path
sys.path.append(os.path.abspath('..'))

# %%
from utils.clique import generate_AG

import numpy as np

# %%
maximal_cliques = [
    [0, 1, 2],
    [2, 3, 4],
    [4, 5]
]
print(generate_AG(6, maximal_cliques))
# Out:
# [[1.  0.5 0.5 0.  0.  0. ]
#  [0.5 1.  0.5 0.  0.  0. ]
#  [0.5 0.5 1.  0.5 0.5 0. ]
#  [0.  0.  0.5 1.  0.5 0. ]
#  [0.  0.  0.5 0.5 1.  0.5]
#  [0.  0.  0.  0.  0.5 1. ]]
